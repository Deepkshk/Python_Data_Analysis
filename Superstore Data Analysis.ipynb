# %% [markdown]
# ## Superstore Data Analysis using Python Libraries

# %%
# import Libraries
import pandas as pd # for data analysis
import matplotlib.pyplot as plt # for visuals and this is the root of seaborn
import seaborn as sb # for visuals

# %%
# read and upload Superstore Data
superstore=pd.read_excel('Superstore.xls',sheet_name='Orders')

# %% [markdown]
# ### Step - 1 ----- Understand the Data

# %%
superstore # complete Data or Dataframe
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 1          2  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 2          3  CA-2020-138688 2020-06-12 2020-06-16    Second Class
# 3          4  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# 4          5  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2018-110422 2018-01-21 2018-01-23    Second Class
# 9990    9991  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9991    9992  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9992    9993  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9993    9994  CA-2021-119914 2021-05-04 2021-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     ...     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...     33180.0   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...     92627.0    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...     92627.0    West  TEC-PH-10003645       Technology       Phones
# 9992  ...     92627.0    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...     92683.0    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
superstore.shape # check total rows and columns
# Out:
# (9994, 21)

# %%
superstore.columns # to see all columns name
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
superstore.head() # for first 5 rows
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2       3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3       4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4       5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
superstore.tail() # for last 5 rows
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2018-110422 2018-01-21 2018-01-23    Second Class
# 9990    9991  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9991    9992  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9992    9993  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9993    9994  CA-2021-119914 2021-05-04 2021-05-09    Second Class
#
#      Customer ID     Customer Name   Segment Country/Region         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 9989     33180.0   South  FUR-FU-10001889        Furniture  Furnishings
# 9990     92627.0    West  FUR-FU-10000747        Furniture  Furnishings
# 9991     92627.0    West  TEC-PH-10003645       Technology       Phones
# 9992     92627.0    West  OFF-PA-10004041  Office Supplies        Paper
# 9993     92683.0    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 9989                             Ultra Door Pull Handle   25.248         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [5 rows x 21 columns]

# %%
superstore.info() # to see the structure of data or dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
#  17  Sales           9994 non-null   float64
#  18  Quantity        9994 non-null   int64
#  19  Discount        9994 non-null   float64
#  20  Profit          9994 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(13)
# memory usage: 1.6+ MB

# %%
superstore.dtypes # check data type of all columns
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State                     object
# Postal Code              float64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
superstore.nunique() # check unique values in all columns
# Out:
# Row ID            9994
# Order ID          5009
# Order Date        1236
# Ship Date         1334
# Ship Mode            4
# Customer ID        793
# Customer Name      793
# Segment              3
# Country/Region       1
# City               531
# State               49
# Postal Code        630
# Region               4
# Product ID        1862
# Category             3
# Sub-Category        17
# Product Name      1849
# Sales             6144
# Quantity            14
# Discount            12
# Profit            7545
# dtype: int64

# %% [markdown]
# ### Step - 2 ------- Cleaning the Data

# %%
# 1. first check the null values in data frame, if any-
superstore.isnull().sum()  
# result shows Postal Code column have 11 null values and we also don't need this column so we drop this
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %%
# Drop Postal code column 
superstore.drop('Postal Code',axis=1,inplace=True)

# %%
superstore.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2       3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3       4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4       5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#   Region       Product ID         Category Sub-Category  \
# 0  South  FUR-BO-10001798        Furniture    Bookcases
# 1  South  FUR-CH-10000454        Furniture       Chairs
# 2   West  OFF-LA-10000240  Office Supplies       Labels
# 3  South  FUR-TA-10000577        Furniture       Tables
# 4  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
superstore.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State             0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
# 2. drop duplicate values, if any
superstore.drop_duplicates()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 1          2  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 2          3  CA-2020-138688 2020-06-12 2020-06-16    Second Class
# 3          4  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# 4          5  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2018-110422 2018-01-21 2018-01-23    Second Class
# 9990    9991  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9991    9992  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9992    9993  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9993    9994  CA-2021-119914 2021-05-04 2021-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#            State Region       Product ID         Category Sub-Category  \
# 0       Kentucky  South  FUR-BO-10001798        Furniture    Bookcases
# 1       Kentucky  South  FUR-CH-10000454        Furniture       Chairs
# 2     California   West  OFF-LA-10000240  Office Supplies       Labels
# 3        Florida  South  FUR-TA-10000577        Furniture       Tables
# 4        Florida  South  OFF-ST-10000760  Office Supplies      Storage
# ...          ...    ...              ...              ...          ...
# 9989     Florida  South  FUR-FU-10001889        Furniture  Furnishings
# 9990  California   West  FUR-FU-10000747        Furniture  Furnishings
# 9991  California   West  TEC-PH-10003645       Technology       Phones
# 9992  California   West  OFF-PA-10004041  Office Supplies        Paper
# 9993  California   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 20 columns]

# %%
superstore.shape
# Out:
# (9994, 20)

# %%
# set no. of visible rows 
pd.set_option('display.max_rows',100) # row no.

# %% [markdown]
# #### So, this data has been cleaned.

# %% [markdown]
# #### and now we could move forward to step 3 (Analysis)

# %%
superstore.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2       3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3       4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4       5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#   Region       Product ID         Category Sub-Category  \
# 0  South  FUR-BO-10001798        Furniture    Bookcases
# 1  South  FUR-CH-10000454        Furniture       Chairs
# 2   West  OFF-LA-10000240  Office Supplies       Labels
# 3  South  FUR-TA-10000577        Furniture       Tables
# 4  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# ### Step - 3 ----- Analysis

# %%
# 1. First we check Total Sale
superstore['Sales'].sum().round(2)
# Out:
# 2297200.86

# %%
# 2. Now we check Total Profit
superstore['Profit'].sum().round(2)
# Out:
# 286397.02

# %%
# 3. We check the Total Quantity Sold
superstore['Quantity'].sum()
# Out:
# 37873

# %%
# We want to check Total Sale by Category
superstore.groupby(by="Category").Sales.sum().round(2)
# Out:
# Category
# Furniture          741999.80
# Office Supplies    719047.03
# Technology         836154.03
# Name: Sales, dtype: float64

# %%
# We want to check Total Profit by Category
superstore.groupby(by='Category').Profit.sum().round(2)
# Out:
# Category
# Furniture           18451.27
# Office Supplies    122490.80
# Technology         145454.95
# Name: Profit, dtype: float64

# %%
# We want to check Total Sale and Total Profit by Category & Sub-Category
superstore.pivot_table(index=['Category','Sub-Category'],values=['Sales','Profit'],aggfunc='sum')
# Out:
#                                   Profit        Sales
# Category        Sub-Category
# Furniture       Bookcases     -3472.5560  114879.9963
#                 Chairs        26590.1663  328449.1030
#                 Furnishings   13059.1436   91705.1640
#                 Tables       -17725.4811  206965.5320
# Office Supplies Appliances    18138.0054  107532.1610
#                 Art            6527.7870   27118.7920
#                 Binders       30221.7633  203412.7330
#                 Envelopes      6964.1767   16476.4020
#                 Fasteners       949.5182    3024.2800
#                 Labels         5546.2540   12486.3120
#                 Paper         34053.5693   78479.2060
#                 Storage       21278.8264  223843.6080
#                 Supplies      -1189.0995   46673.5380
# Technology      Accessories   41936.6357  167380.3180
#                 Copiers       55617.8249  149528.0300
#                 Machines       3384.7569  189238.6310
#                 Phones        44515.7306  330007.0540

# %%
# we want to check Total Sale by Region
superstore.groupby(by='Region').Sales.sum().round(2)
# Out:
# Region
# Central    501239.89
# East       678781.24
# South      391721.90
# West       725457.82
# Name: Sales, dtype: float64

# %%
# we want to check Total Profit  by Region
superstore.groupby(by='Region').Profit.sum().round(2)
# Out:
# Region
# Central     39706.36
# East        91522.78
# South       46749.43
# West       108418.45
# Name: Profit, dtype: float64

# %%
# To see the Total Sale and Total Profit by Region
superstore.pivot_table(index='Region',values=['Sales','Profit'],aggfunc='sum').round(2)
# Out:
#             Profit      Sales
# Region
# Central   39706.36  501239.89
# East      91522.78  678781.24
# South     46749.43  391721.90
# West     108418.45  725457.82

# %%
# we want to check statistical operations with sale and profit column by region, category, sub-category
superstore.pivot_table(index=['Region','Category','Sub-Category'],values=['Sales','Profit'],aggfunc=['sum','max','min','mean','std'])
# Out:
#                                              sum                     max  \
#                                           Profit        Sales     Profit
# Region  Category        Sub-Category
# Central Furniture       Bookcases     -1997.9043   24157.1768   407.1288
#                         Chairs         6592.7221   85230.6460   770.3520
#                         Furnishings   -3906.2168   15254.3700   387.5676
#                         Tables        -3559.6504   39154.9710   350.4270
#         Office Supplies Appliances    -2638.6175   23582.0330   793.7160
#                         Art            1195.1591    5765.3400    54.5844
#                         Binders       -1043.6369   56923.2820  4946.3700
#                         Envelopes      1777.5283    4636.8720   204.0714
#                         Fasteners       236.6186     778.0300    21.8880
#                         Labels         1073.0794    2451.4720   240.8595
#                         Paper          6971.9005   17491.9020   301.9680
#                         Storage        1969.8365   45930.1120   226.3626
#                         Supplies       -661.8881    9467.3720    83.2810
#         Technology      Accessories    7251.6306   33956.0760   829.3754
#                         Copiers       15608.8413   37259.5700  8399.9760
#                         Machines      -1486.0666   26797.3840   679.9960
#                         Phones        12323.0267   72403.2820   743.9880
# East    Furniture       Bookcases     -1167.6318   43819.3340  1013.1270
#                         Chairs         9357.7706   96260.6830   609.7157
#                         Furnishings    5881.4071   29071.3800   272.7920
#                         Tables       -11025.3801   39139.8070    20.9670
#         Office Supplies Appliances     8391.4134   34188.4660   735.0336
#                         Art            1899.9443    7485.7640    83.8680
#                         Binders       11267.9346   53497.9970  1453.1238
#                         Envelopes      1812.4090    4375.8740   162.8640
#                         Fasteners       263.9908     819.7180    18.2400
#                         Labels         1129.2800    2602.9340    56.1752
#                         Paper          9015.3710   20172.6020   219.4416
#                         Storage        8389.3712   71612.5840   792.2691
#                         Supplies      -1155.1352   10760.1160    36.8130
#         Technology      Accessories   11195.8644   45033.3720   762.1845
#                         Copiers       17022.8418   53219.4620  5039.9856
#                         Machines       6928.6429   66106.1650  2400.9657
#                         Phones        12314.6860  100614.9820  1228.1787
# South   Furniture       Bookcases      1339.4918   10899.3620   374.6286
#                         Chairs         6612.0893   45176.4460   746.4078
#                         Furnishings    3442.6829   17306.6840   297.6900
#                         Tables        -4623.0579   43916.1920   493.7856
#         Office Supplies Appliances     4123.9396   19525.3260   694.5015
#                         Art            1058.5866    4655.6220    79.7580
#                         Binders        3900.6640   37030.3410  3177.4750
#                         Envelopes      1465.4770    3345.5560   146.2405
#                         Fasteners       173.7181     503.3160    21.6000
#                         Labels         1040.7723    2353.1800   240.8595
#                         Paper          5947.0614   14150.9840   301.9680
#                         Storage        2274.2965   35768.0600   375.4296
#                         Supplies          1.8773    8318.9280    83.2810
#         Technology      Accessories    7004.5424   27276.7540   653.3010
#                         Copiers        3658.9067    9299.7560  1439.9760
#                         Machines      -1438.8930   53890.9600  2799.9840
#                         Phones        10767.2753   58304.4380   909.9818
# West    Furniture       Bookcases     -1646.5117   36004.1235   259.8896
#                         Chairs         4027.5843  101781.3280   267.6672
#                         Furnishings    7641.2704   30072.7300   297.6900
#                         Tables         1482.6073   84754.5620   629.0100
#         Office Supplies Appliances     8261.2699   30236.3360   654.7554
#                         Art            2374.0970    9212.0660   112.5740
#                         Binders       16096.8016   55961.1130  1906.4850
#                         Envelopes      1908.7624    4118.1000   197.3530
#                         Fasteners       275.1907     923.2160    21.5824
#                         Labels         2303.1223    5078.7260   385.3752
#                         Paper         12119.2364   26663.7180   352.2960
#                         Storage        8645.3222   70532.8520   349.3392
#                         Supplies        626.0465   18127.1220   327.5060
#         Technology      Accessories   16484.5983   61114.1160   742.6320
#                         Copiers       19327.2351   49749.2420  6719.9808
#                         Machines       -618.9264   42444.1220   503.6400
#                         Phones         9110.7426   98684.3520   363.9048
#
#                                                         min            \
#                                            Sales     Profit     Sales
# Region  Category        Sub-Category
# Central Furniture       Bookcases      2396.2656  -437.5404   67.9932
#                         Chairs         3504.9000  -350.4900   26.6400
#                         Furnishings    1336.4400  -427.4500    1.8920
#                         Tables         2678.9400  -566.5625   66.6450
#         Office Supplies Appliances     2405.2000 -1181.2824    0.4440
#                         Art             209.9400     0.3094    1.3440
#                         Binders        9892.7400 -3701.8928    0.5560
#                         Envelopes       604.6560     0.5508    1.6320
#                         Fasteners        58.3680    -3.7680    1.8100
#                         Labels          491.5500     0.6786    2.0880
#                         Paper           629.1000     1.1466    3.5280
#                         Storage        1554.9360  -172.7328    8.7200
#                         Supplies       4164.0500  -786.0144    1.7440
#         Technology      Accessories    1928.7800   -33.3200    1.9800
#                         Copiers       17499.9500   107.9946  319.9840
#                         Machines       8159.9520 -1359.9920   83.9000
#                         Phones         2735.9520   -87.6672    5.5000
# East    Furniture       Bookcases      4404.9000 -1665.0522   35.4900
#                         Chairs         4416.1740  -630.8820   47.9920
#                         Furnishings    1049.2000   -68.3920    2.9600
#                         Tables         2065.3200  -734.5264   27.4140
#         Office Supplies Appliances     2625.1200     0.4440    2.2200
#                         Art             289.2000     0.1692    1.5040
#                         Binders        4355.1680  -913.1760    0.8520
#                         Envelopes       361.9200     0.9588    2.0400
#                         Fasteners        40.6700    -2.3814    1.2400
#                         Labels          122.1200     1.0738    3.1500
#                         Paper           447.8400     1.0700    3.3800
#                         Storage        2934.3300  -337.8060    8.3840
#                         Supplies       4663.7360 -1049.3406    3.4880
#         Technology      Accessories    2309.6500   -75.5958    2.9700
#                         Copiers       11199.9680    59.9980  479.9840
#                         Machines       9099.9300 -6599.9780   12.5850
#                         Phones         4548.8100  -386.3916    2.9700
# South   Furniture       Bookcases      1628.8200   -81.4410   61.9600
#                         Chairs         2803.9200  -182.6370   33.9400
#                         Furnishings    1196.8600   -51.2940    2.7840
#                         Tables         4297.6440 -1862.3124   79.9740
#         Office Supplies Appliances     2104.5500     0.5244    5.2000
#                         Art             265.8600     0.1533    1.3440
#                         Binders        6354.9500 -1306.5504    1.1670
#                         Envelopes       311.1500     0.9774    2.8960
#                         Fasteners        55.1040     0.1134    1.9840
#                         Labels          491.5500     0.9963    2.6100
#                         Paper           629.1000     1.0700    3.4240
#                         Storage        1801.6320  -337.8060    4.4640
#                         Supplies       4164.0500  -204.3145    2.9440
#         Technology      Accessories    2249.9100   -75.5958    1.5840
#                         Copiers        2999.9500    89.9970  479.9840
#                         Machines      22638.4800 -3839.9904   32.9850
#                         Phones         4367.8960   -32.3838    7.9200
# West    Furniture       Bookcases      3406.6640  -786.7440   48.5800
#                         Chairs         2803.9200  -219.1644   40.7840
#                         Furnishings    1049.2000   -36.4704    3.4800
#                         Tables         3610.8480  -814.4832   24.3680
#         Office Supplies Appliances     2518.2900     0.2925    2.6000
#                         Art            1113.0240     0.1584    1.4080
#                         Binders        5083.9600  -694.2936    1.0800
#                         Envelopes       419.9000     1.9176    4.0800
#                         Fasteners        93.3600   -11.8256    1.8100
#                         Labels          786.4800     1.2006    2.6100
#                         Paper           733.9500     1.8144    4.2800
#                         Storage        1856.1900  -167.2700    5.9800
#                         Supplies       8187.6500  -299.8116    5.8400
#         Technology      Accessories    3347.3700   -35.9928    0.9900
#                         Copiers       13999.9600    59.9980  299.9900
#                         Machines       4799.9840 -3399.9800   11.5600
#                         Phones         4158.9120  -131.5008    5.5600
#
#                                             mean                       std  \
#                                           Profit        Sales       Profit
# Region  Category        Sub-Category
# Central Furniture       Bookcases     -39.958086   483.143536   115.294239
#                         Chairs         42.809884   553.445753   173.356195
#                         Furnishings   -19.054716    74.411561    80.447853
#                         Tables        -49.439589   543.819042   177.485857
#         Office Supplies Appliances    -21.452175   191.723846   211.238591
#                         Art             6.790677    32.757614     9.654045
#                         Binders        -2.851467   155.528093   512.467995
#                         Envelopes      30.127598    78.591051    40.111530
#                         Fasteners       4.302156    14.146000     5.460897
#                         Labels         14.119466    32.256211    30.299334
#                         Paper          21.719316    54.491907    33.376757
#                         Storage         9.380174   218.714819    49.192077
#                         Supplies      -18.385781   262.982556   132.589307
#         Technology      Accessories    39.626397   185.552328    85.491733
#                         Copiers       975.552581  2328.723125  2049.424763
#                         Machines      -70.765076  1276.065905   370.789516
#                         Phones         61.615133   362.016410    95.343621
# East    Furniture       Bookcases     -16.680454   625.990486   261.574919
#                         Chairs         55.701015   572.980256   135.557593
#                         Furnishings    20.782357   102.725724    36.645219
#                         Tables       -137.817251   489.247588   148.090304
#         Office Supplies Appliances     66.598519   271.337032   117.981593
#                         Art             8.333089    32.832298    12.789838
#                         Binders        25.608942   121.586357   166.584275
#                         Envelopes      24.492014    59.133432    29.740640
#                         Fasteners       4.327718    13.438000     4.595941
#                         Labels         10.554019    24.326486    11.453043
#                         Paper          23.850188    53.366672    32.152908
#                         Storage        34.666823   295.919769   114.869731
#                         Supplies      -20.627414   192.144929   144.371703
#         Technology      Accessories    54.348856   218.608602   113.793223
#                         Copiers       851.142090  2660.973100  1389.711941
#                         Machines      187.260619  1786.653108  1563.660310
#                         Phones         45.274581   369.908022   155.571117
# South   Furniture       Bookcases      47.838993   389.262929    99.635394
#                         Chairs         75.137378   513.368705   124.241819
#                         Furnishings    20.864745   104.888994    39.019449
#                         Tables        -90.648194   861.101804   393.674387
#         Office Supplies Appliances     50.912835   241.053407    98.379713
#                         Art             7.454835    32.786070    12.773680
#                         Binders        15.856358   150.529841   301.165713
#                         Envelopes      27.138463    61.954741    32.619680
#                         Fasteners       5.990279    17.355724     5.787274
#                         Labels         16.011882    36.202769    37.931125
#                         Paper          26.909780    64.031602    40.907249
#                         Storage        17.767941   279.437969    68.824300
#                         Supplies        0.064734   286.859586    43.280140
#         Technology      Accessories    54.722987   213.099641   100.787927
#                         Copiers       522.700957  1328.536571   473.006448
#                         Machines      -79.938500  2993.942222  1356.849378
#                         Phones         76.909109   416.460271   124.917573
# West    Furniture       Bookcases     -20.581396   450.051544   148.286806
#                         Chairs         19.456929   491.697237    58.652540
#                         Furnishings    25.135758    98.923454    37.647688
#                         Tables         12.781097   730.642776   187.391534
#         Office Supplies Appliances     60.744632   222.326000   110.553212
#                         Art             9.496388    36.848264    16.170927
#                         Binders        34.175800   118.813403   160.662836
#                         Envelopes      28.488991    61.464179    39.083127
#                         Fasteners       3.822093    12.822444     4.755957
#                         Labels         19.854503    43.782121    45.865031
#                         Paper          26.931636    59.252707    35.875552
#                         Storage        32.501211   265.161098    69.726538
#                         Supplies        9.073138   262.711913    59.127924
#         Technology      Accessories    63.893792   236.876419   114.752679
#                         Copiers       773.089404  1989.969680  1305.090672
#                         Machines      -15.869908  1088.310821   611.521729
#                         Phones         32.890768   356.261199    48.041375
#
#
#                                             Sales
# Region  Category        Sub-Category
# Central Furniture       Bookcases      440.019759
#                         Chairs         572.431644
#                         Furnishings    140.302714
#                         Tables         447.162244
#         Office Supplies Appliances     355.230569
#                         Art             39.956992
#                         Binders        824.051844
#                         Envelopes      107.990685
#                         Fasteners       13.115614
#                         Labels          61.873036
#                         Paper           79.243089
#                         Storage        265.848059
#                         Supplies       933.352421
#         Technology      Accessories    271.397453
#                         Copiers       4222.593752
#                         Machines      1813.715477
#                         Phones         444.917752
# East    Furniture       Bookcases      917.401096
#                         Chairs         644.381362
#                         Furnishings    152.577444
#                         Tables         412.234273
#         Office Supplies Appliances     441.556249
#                         Art             47.263286
#                         Binders        408.012910
#                         Envelopes       72.379664
#                         Fasteners        9.981727
#                         Labels          25.576830
#                         Paper           69.717467
#                         Storage        447.088367
#                         Supplies       640.215652
#         Technology      Accessories    362.164786
#                         Copiers       3398.844349
#                         Machines      2224.684915
#                         Phones         484.270109
# South   Furniture       Bookcases      339.586581
#                         Chairs         499.147878
#                         Furnishings    162.794857
#                         Tables         805.139532
#         Office Supplies Appliances     346.700944
#                         Art             47.552800
#                         Binders        541.700812
#                         Envelopes       71.094251
#                         Fasteners       12.792869
#                         Labels          79.814140
#                         Paper           90.237973
#                         Storage        352.842552
#                         Supplies       823.671807
#         Technology      Accessories    322.338272
#                         Copiers        821.356656
#                         Machines      5539.237155
#                         Phones         612.955714
# West    Furniture       Bookcases      506.640021
#                         Chairs         465.129491
#                         Furnishings    139.058562
#                         Tables         689.289148
#         Office Supplies Appliances     390.159149
#                         Art             84.205837
#                         Binders        436.650507
#                         Envelopes       83.362512
#                         Fasteners       13.534298
#                         Labels         102.508282
#                         Paper           77.710032
#                         Storage        320.150390
#                         Supplies      1144.256012
#         Technology      Accessories    358.715315
#                         Copiers       2690.711896
#                         Machines      1231.201926
#                         Phones         462.123287

# %%
# We want to see the correlation between Profit and Sale
superstore[['Sales','Profit']].corr() # Result shows the Positive Correlation
# Out:
#            Sales    Profit
# Sales   1.000000  0.479064
# Profit  0.479064  1.000000

# %%
# we want to see, what is total sole by year and for that we need to extract year form order date column
superstore['year']=superstore['Order Date'].dt.year

# %%
superstore.groupby(by='year').Sales.sum().round(2)
# the result shows sale is incresing per year
# Out:
# year
# 2018    484247.50
# 2019    470532.51
# 2020    609205.60
# 2021    733215.26
# Name: Sales, dtype: float64

# %%
# we want to see, what is the total profit by year
superstore.groupby(by='year').Profit.sum().round(2) # the result shows profit is also increasing per year
# Out:
# year
# 2018    49543.97
# 2019    61618.60
# 2020    81795.17
# 2021    93439.27
# Name: Profit, dtype: float64

# %%
# Statistical operations in all numeric columns
superstore.describe()
# Out:
#             Row ID         Sales     Quantity     Discount       Profit  \
# count  9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000    229.858001     3.789574     0.156203    28.656896
# std    2885.163629    623.245101     2.225110     0.206452   234.260108
# min       1.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    2499.250000     17.280000     2.000000     0.000000     1.728750
# 50%    4997.500000     54.490000     3.000000     0.200000     8.666500
# 75%    7495.750000    209.940000     5.000000     0.200000    29.364000
# max    9994.000000  22638.480000    14.000000     0.800000  8399.976000
#
#               year
# count  9994.000000
# mean   2019.722233
# std       1.123555
# min    2018.000000
# 25%    2019.000000
# 50%    2020.000000
# 75%    2021.000000
# max    2021.000000

# %%
# we want to see, what is the total sale by States
superstore.groupby(by='State').Sales.sum().round(2)
# Out:
# State
# Alabama                  19510.64
# Arizona                  35282.00
# Arkansas                 11678.13
# California              457687.63
# Colorado                 32108.12
# Connecticut              13384.36
# Delaware                 27451.07
# District of Columbia      2865.02
# Florida                  89473.71
# Georgia                  49095.84
# Idaho                     4382.49
# Illinois                 80166.10
# Indiana                  53555.36
# Iowa                      4579.76
# Kansas                    2914.31
# Kentucky                 36591.75
# Louisiana                 9217.03
# Maine                     1270.53
# Maryland                 23705.52
# Massachusetts            28634.43
# Michigan                 76269.61
# Minnesota                29863.15
# Mississippi              10771.34
# Missouri                 22205.15
# Montana                   5589.35
# Nebraska                  7464.93
# Nevada                   16729.10
# New Hampshire             7292.52
# New Jersey               35764.31
# New Mexico                4783.52
# New York                310876.27
# North Carolina           55603.16
# North Dakota               919.91
# Ohio                     78258.14
# Oklahoma                 19683.39
# Oregon                   17431.15
# Pennsylvania            116511.91
# Rhode Island             22627.96
# South Carolina            8481.71
# South Dakota              1315.56
# Tennessee                30661.87
# Texas                   170188.05
# Utah                     11220.06
# Vermont                   8929.37
# Virginia                 70636.72
# Washington              138641.27
# West Virginia             1209.82
# Wisconsin                32114.61
# Wyoming                   1603.14
# Name: Sales, dtype: float64

# %% [markdown]
# #### So, now we create some Visuals to find meaningful information easily

# %%
# 1. First we want to see, the sales trend by year using Line Chart
sb.set(rc={'figure.figsize':(15,8)})
sb.lineplot(data=superstore,x='year',y='Sales',estimator=sum)
# Out:
# <AxesSubplot: xlabel='year', ylabel='Sales'>

# %%
# We want to see, the Profit trend by year using line plot
sb.lineplot(data=superstore,x='year',y='Profit',estimator=sum)
# Out:
# <AxesSubplot: xlabel='year', ylabel='Profit'>

# %%
# we want to know the relationship between Totle Sale and Total Profit using Scatter plot
sb.scatterplot(x=superstore.Sales,y=superstore.Profit)
# Out:
# <AxesSubplot: xlabel='Sales', ylabel='Profit'>

# %%
# we want to know the relationship between Totle Sale and Total Profit according to Category using Scatter plot
sb.scatterplot(x=superstore.Sales,y=superstore.Profit,hue=superstore.Category)
# Out:
# <AxesSubplot: xlabel='Sales', ylabel='Profit'>

# %%
# we want to know the relationship between Totle Sale and Total Profit according to sub-Category using Scatter plot
subc=superstore['Sub-Category']
sb.scatterplot(x=superstore.Sales,y=superstore.Profit,hue=subc)
# Out:
# <AxesSubplot: xlabel='Sales', ylabel='Profit'>

# %%
# Check and find the details where sale is less than 5000 and loss is huge
superstore[(superstore.Sales<5000) & (superstore.Profit<-6000)]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 7772    7773  CA-2020-108196 2020-11-25 2020-12-02  Standard Class
#
#      Customer ID  Customer Name   Segment Country/Region       City  ...  \
# 7772    CS-12505  Cindy Stewart  Consumer  United States  Lancaster  ...
#
#      Region       Product ID    Category Sub-Category  \
# 7772   East  TEC-MA-10000418  Technology     Machines
#
#                                    Product Name     Sales  Quantity  Discount  \
# 7772  Cubify CubeX 3D Printer Double Head Print  4499.985         5       0.7
#
#         Profit  year
# 7772 -6599.978  2020
#
# [1 rows x 21 columns]

# %%
# We want to know the order wise ratio of Category
plt.pie(superstore.Category.value_counts().values,labels=superstore.Category.value_counts().index,autopct='%.2f%%')
plt.show()

# %%
# We want to know the order wise ratio of Sub-Category
subx=superstore['Sub-Category'].value_counts().values
subls=superstore['Sub-Category'].value_counts().index
plt.pie(subx,labels=subls,autopct='%.2f%%')
plt.show()

# %%
# we want to know, Region wise Total Sale
sb.set(rc={'figure.figsize':(15,8)})
a=sb.barplot(x=superstore.Region,y=superstore.Sales,estimator=sum)
for i in a.containers:
    a.bar_label(i,)

# %%
# we want to know, Profit by Region
a=sb.barplot(x=superstore.Region,y=superstore.Profit,estimator=sum)
for i in a.containers:
    a.bar_label(i,)

# %%
# we want to know, Total sale by Category acc. to Region
a=sb.barplot(x=superstore.Region,y=superstore.Sales,estimator=sum,hue=superstore.Category)
for i in a.containers:
    a.bar_label(i,)

# %%
# we want to know, the Total Profit by Category acc. to Region
a=sb.barplot(x=superstore.Region,y=superstore.Profit,estimator=sum,hue=superstore.Category)
for i in a.containers:
    a.bar_label(i,)

# %%
# we want to know the category wise total profit
a=sb.barplot(x=superstore.Category,y=superstore.Profit,estimator=sum)
for i in a.containers:
    a.bar_label(i,)

# %%
# we want to know the state wise total profit
sb.set(rc={'figure.figsize':(15,15)})
a=sb.barplot(x=superstore.Profit,y=superstore.State,estimator=sum)
for i in a.containers:
    a.bar_label(i,)

# %%
# we want to know the category wise total profit in all years
sb.set(rc={'figure.figsize':(15,8)})
a=sb.barplot(x=superstore.Category,y=superstore.Profit,estimator=sum,hue=superstore.year)
for i in a.containers:
    a.bar_label(i,)

# %% [markdown]
# #### So,the conclusion of this Analysis is -

# %% [markdown]
# ##### 1. The sale and Profit of Superstore is increasing
# ##### 2. The most Prifitable Category is Technology and the Furniture is so much less Profitable.
# ##### 3. The most Profitable State is California. and we face so much lose in Texas.
# ##### 4. The most profitabe Region is West
